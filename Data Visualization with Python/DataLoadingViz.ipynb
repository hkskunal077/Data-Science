# %%
import numpy as np
import pandas as pd

df_can = pd.read_excel('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx',
                       sheet_name = 'Canada by Citizenship', skiprows = 20, skipfooter = 2)
print('Data Read into a pandas dataframe')
# Out:
# Data Read into a pandas dataframe

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
df_can.tail()
# Out:
#            Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 190  Immigrants  Foreigners        Viet Nam   935  ...  1942  1723  1731  2112
# 191  Immigrants  Foreigners  Western Sahara   903  ...     0     0     0     0
# 192  Immigrants  Foreigners           Yemen   935  ...   211   160   174   217
# 193  Immigrants  Foreigners          Zambia   903  ...   102    69    46    59
# 194  Immigrants  Foreigners        Zimbabwe   903  ...   494   434   437   407
#
# [5 rows x 43 columns]

# %%
print(df_can.info(verbose=False), "\n")
print(df_can.columns, "\n", df_can.index, "\n", df_can.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Columns: 43 entries, Type to 2013
# dtypes: int64(37), object(6)
# memory usage: 65.6+ KB
# None
#
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')
#  RangeIndex(start=0, stop=195, step=1)
#  (195, 43)

# %%
df_can.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1, inplace=True)
df_can.head()
# Out:
#            OdName AreaName          RegName  ...  2011  2012  2013
# 0     Afghanistan     Asia    Southern Asia  ...  2203  2635  2004
# 1         Albania   Europe  Southern Europe  ...   539   620   603
# 2         Algeria   Africa  Northern Africa  ...  4325  3774  4331
# 3  American Samoa  Oceania        Polynesia  ...     0     0     0
# 4         Andorra   Europe  Southern Europe  ...     0     1     1
#
# [5 rows x 38 columns]

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can.columns
# Out:
# Index([  'Country', 'Continent',    'Region',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
df_can['Total'] = df_can.sum(axis=1)
print(list(df_can.isnull().sum())[:4])
# Out:
# [0, 0, 0, 0]

# %%
df_can.describe()
# Out:
#                1980          1981  ...          2013         Total
# count    195.000000    195.000000  ...    195.000000  1.950000e+02
# mean     508.394872    566.989744  ...   1320.702564  1.972047e+05
# std     1949.588546   2152.643752  ...   4237.951988  5.507130e+05
# min        0.000000      0.000000  ...      0.000000  6.000000e+00
# 25%        0.000000      0.000000  ...     45.000000  5.712000e+03
# 50%       13.000000     10.000000  ...    213.000000  3.010800e+04
# 75%      251.500000    295.500000  ...    796.000000  1.334370e+05
# max    22045.000000  24796.000000  ...  34129.000000  4.151424e+06
#
# [8 rows x 35 columns]

# %%
# df['column'] # For Series
# df[['column1', 'column2']] # For Dataframe.

# df_can.iloc[index]
# df_can.loc[label] #For filtering by position or labels

# %%
df_can.Country
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: Country, Length: 195, dtype: object

# %%
df_can[['Country', 1980, 1981, 1982, 1983, 1984, 1985]]
# Out:
#             Country  1980  1981  1982  1983  1984  1985
# 0       Afghanistan    16    39    39    47    71   340
# 1           Albania     1     0     0     0     0     0
# 2           Algeria    80    67    71    69    63    44
# 3    American Samoa     0     1     0     0     0     0
# 4           Andorra     0     0     0     0     0     0
# ..              ...   ...   ...   ...   ...   ...   ...
# 190        Viet Nam  1191  1829  2162  3404  7583  5907
# 191  Western Sahara     0     0     0     0     0     0
# 192           Yemen     1     2     1     6     0    18
# 193          Zambia    11    17    11     7    16     9
# 194        Zimbabwe    72   114   102    44    32    29
#
# [195 rows x 7 columns]

# %%
df_can.loc['Japan'] is df_can.iloc[87]
# Out:
# False

# %%
#Slice by using indexing
df_can[df_can.index == 'Japan']
# Out:
#         Continent        Region            DevName  ...  2012  2013   Total
# Country                                             ...
# Japan        Asia  Eastern Asia  Developed regions  ...  1214   982  166242
#
# [1 rows x 38 columns]

# %%
#We can also extract in the form Matrix(i, j)
print(df_can.loc['Japan', 2013], "\n")
print(df_can.loc['Japan', [1980, 1981, 1982, 1983, 1984]])
# Out:
# 982
#
# 1980    701
# 1981    756
# 1982    598
# 1983    309
# 1984    246
# Name: Japan, dtype: object

# %%
#Converting them into strings the value of the year
df_can.columns = list(map(str, df_can.columns))
[(type(x)) for x in df_can.columns.values]
years = list(map(str, range(1980, 1985)))

# %%
condition = df_can['Continent'] == 'Asia'
condition
# Out:
# Country
# Afghanistan        True
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# Viet Nam           True
# Western Sahara    False
# Yemen              True
# Zambia            False
# Zimbabwe          False
# Name: Continent, Length: 195, dtype: bool

# %%
#We can consteruct a boolean condition for the value so tahat whenever need to pout the value'
df_can[condition]
# Out:
#                                                Continent  ...    Total
# Country                                                   ...
# Afghanistan                                         Asia  ...   351834
# Armenia                                             Asia  ...    19860
# Azerbaijan                                          Asia  ...    15894
# Bahrain                                             Asia  ...     2850
# Bangladesh                                          Asia  ...   393408
# Bhutan                                              Asia  ...    35256
# Brunei Darussalam                                   Asia  ...     3600
# Cambodia                                            Asia  ...    39228
# China                                               Asia  ...  3959772
# China, Hong Kong Special Administrative Region      Asia  ...    55962
# China, Macao Special Administrative Region          Asia  ...     1704
# ...

# %%
#Extraction based on the indexes based on the extracted values from other extracted values
df_can[(df_can['Continent'] == 'Asia') & (df_can['Region'] == 'Southern Asia')]
# Out:
#                            Continent         Region  ...   2013    Total
# Country                                              ...
# Afghanistan                     Asia  Southern Asia  ...   2004   351834
# Bangladesh                      Asia  Southern Asia  ...   3789   393408
# Bhutan                          Asia  Southern Asia  ...    487    35256
# India                           Asia  Southern Asia  ...  33087  4151424
# Iran (Islamic Republic of)      Asia  Southern Asia  ...  11291  1055538
# Maldives                        Asia  Southern Asia  ...      1      180
# Nepal                           Asia  Southern Asia  ...   1308    61332
# Pakistan                        Asia  Southern Asia  ...  12603  1449600
# Sri Lanka                       Asia  Southern Asia  ...   2394   890148
#
# [9 rows x 38 columns]

# %%
print('data dimension', df_can.shape)
print(df_can.columns)
df_can.head(2)
# Out:
# data dimension (195, 38)
# Index(['Continent', 'Region', 'DevName', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', 'Total'],
#       dtype='object')
#             Continent           Region             DevName  ...  2012  2013   Total
# Country                                                     ...
# Afghanistan      Asia    Southern Asia  Developing regions  ...  2635  2004  351834
# Albania        Europe  Southern Europe   Developed regions  ...   620   603   94194
#
# [2 rows x 38 columns]

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
print('Matplotlib Version: ', mpl.__version__)
print(plt.style.available)
print(mpl.style.use(['ggplot']))
# Out:
# Matplotlib Version:  3.2.2
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
# None

# %%
haiti = df_can.loc['Haiti', years]
haiti.head()
# Out:
# 1980    1666
# 1981    3692
# 1982    3498
# 1983    2860
# 1984    1418
# Name: Haiti, dtype: object

# %%
haiti.plot()

# %%
haiti.index = haiti.index.map(int)
haiti.plot(kind='line')

plt.title('Immigration from Haiti')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.plot()
plt.show()
plt.close()
